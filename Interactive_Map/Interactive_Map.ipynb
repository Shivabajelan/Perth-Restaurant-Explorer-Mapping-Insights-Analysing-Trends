# %% [markdown]
# ### Load Dependencies

# %%
import pandas as pd
import sqlite3
import folium
from folium import FeatureGroup, Popup, Marker
from folium import IFrame
import matplotlib.pyplot as plt

# %%
### Load Dataset - Prior to sqlite database storage - now commented out

# %%
# data = pd.read_csv('Interactive_Map_data.csv', nrows=532)

# %%
### Open and load initial sqlite data bas - now comment out

# %%
#'interactive_map.db' is the name of the SQLite database file
conn = sqlite3.connect('interactive_map.db')

# %%
### Initial setup loading data to sqlite database. now comment out

# %%
# data.to_sql('interactive_data', conn, if_exists='replace', index=False)

# %%
# Close sqlite database - now commented out.
conn.close()

# %%
### Open sqlite database to read data file and convert to dataframe

# %%
conn = sqlite3.connect('interactive_map.db')

# %%
data_from_sql = pd.read_sql_query('SELECT * FROM interactive_data', conn)

# %%
conn.close()

# %%
### DataFrame loaded from sqlite database.Database disconnected.

# %% [markdown]
# ### Inspect Data, Confirm 'rating', 'latitude', and 'longitude', are 'float'

# %%
#Inspect the data
#print(data.head())  # Print the first few rows of the dataset
#print(data.dtypes)  # Check the data types of each column
#print(data.isnull().sum())  # Check for any missing values

# Ensure latitude and longitude are floats
data['rating'] = data['rating'].astype(float)
data['latitude'] = data['latitude'].astype(float)
data['longitude'] = data['longitude'].astype(float)

# %% [markdown]
# ### Extract 'categories', and confirm.

# %%
# Assuming you've already loaded your data into a DataFrame called 'data'
unique_categories = data['categories'].astype(str).unique()

# Sort the unique categories in alphabetical order
sorted_categories = sorted(unique_categories)

# Save or display the map
#mperth.save('restaurants_map_full.html')
#for category in sorted_categories:
#print(category)

# %% [markdown]
# ### Initialise the Map

# %%
# Initialize the map
mperth = folium.Map(location=[-31.9514, 115.8617], zoom_start=15)

# Define Layer Groups for categories, prices, and ratings
categories = ['American', 'AsianFusion', 'AsianOther', 'Australian', 'Chinese', 'CoffeeShop', 'European', 'FastFood', 'Indian', 'Italian/Pizza', 'Japanese', 'Mexican', 'MiddleEast', 'Other', 'Vietnamese']
price_ranges = ["$", "$$", "$$$", "$$$$"]

# Define Layer Groups for categories, prices, and ratings
category_layers = {category: folium.FeatureGroup(name=category) for category in categories}
price_layers = {price: folium.FeatureGroup(name=price) for price in price_ranges}
rating_layers = {"high": folium.FeatureGroup(name="Rating >= 4.0"), "low": folium.FeatureGroup(name="Rating < 4.0")}

# Create and add markers to their respective layers based on the restaurant data
for index, row in data.iterrows():
    # Define popup content
    popup_content = (f"<strong>Name:</strong> {row['business_name']}<br>"
                     f"<strong>Category:</strong> {row['categories']}<br>"
                     f"<strong>Activities:</strong> {row['activities']}<br><br>"
                     f"<strong>Price:</strong> {row['price']}&nbsp;&nbsp;&nbsp;&nbsp;"  # Using HTML entity for spaces
                     f"<strong>Rating:</strong> {row['rating']}&nbsp;&nbsp;&nbsp;&nbsp;"
                     f"<strong>Reviews:</strong> {row['review_count']}<br>"
                     f"<strong>Address:</strong> {row['address']}<br>"
                     f"<strong>Phone:</strong> {row['phone']}<br>")
                     
    # Create a new markerFor each category, price, and rating. 
    # Add to Category Layer
    if row['categories'] in category_layers:
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=folium.Popup(popup_content, max_width=250),
            tooltip='Click for further information'
        ).add_to(category_layers[row['categories']])
    
    # Add to Price Layer
    if row['price'] in price_layers:
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=folium.Popup(popup_content, max_width=300),
            tooltip='Click for further information'
        ).add_to(price_layers[row['price']])
    
    # Add to Rating Layer
    rating_key = "high" if row['rating'] >= 4.0 else "low"
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=folium.Popup(popup_content, max_width= 300),
        tooltip='Click for further information'
    ).add_to(rating_layers[rating_key])

# Add all layers to the map
for layer in category_layers.values():
    mperth.add_child(layer)
for layer in price_layers.values():
    mperth.add_child(layer)
for layer in rating_layers.values():
    mperth.add_child(layer)

# Add LayerControl to manage layer visibility
folium.LayerControl().add_to(mperth)

# Save the map
mperth.save('interactive_map.html')

mperth
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_601aa3c90975f65d59d4aacc83fc2323 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_601aa3c90975f65d59d4aacc83fc2323&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_601aa3c90975f65d59d4aacc83fc2323 = L.map(
#                 &quot;map_601aa3c90975f65d59d4aacc83fc2323&quot;,
#                 {
#                     center: [-31.9514, 115.8617],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_322bf616bcd5f30230a260973661e176 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_322bf616bcd5f30230a260973661e176.addTo(map_601aa3c90975f65d59d4aacc83fc2323);
#
#
#             var feature_group_c6190a4b210b68f75c12bbbd78f531d8 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_0c81644c36fbb4da0a08e69e62e7cfc3 = L.marker(
#                 [-31.94623, 115.85756],
#                 {}
#             ).addTo(feature_group_c6190a4b210b68f75c12bbbd78f531d8);
#
#
#         var popup_171ab074b3a3be19878bcd23d229ead5 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_8859ac70d6c8b49392c492d4646b3a02 = $(`&lt;div id=&quot;html_8859ac70d6c8b49392c492d4646b3a02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Name:&lt;/strong&gt; Smokey&#x27;s Cabin&lt;br&gt;&lt;strong&gt;Category:&lt;/strong&gt; American&lt;br&gt;&lt;strong&gt;Activities:&lt;/strong&gt; Burgers, Pizza&lt;br&gt;&lt;br&gt;&lt;strong&gt;Price:&lt;/strong&gt; $$&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&lt;strong&gt;Rating:&lt;/strong&gt; 4.1&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&lt;strong&gt;Reviews:&lt;/strong&gt; 8&lt;br&gt;&lt;strong&gt;Address:&lt;/strong&gt; 71-73 Lake St, Northbridge, 6003&lt;br&gt;&lt;strong&gt;Phone:&lt;/strong&gt; +61 487 600 060&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_171ab074b3a3be19878bcd23d229ead5.setContent(html_8859ac70d6c8b49392c492d4646b3a02);
#
#
#
#         marker_0c81644c36fbb4da0a08e69e62e7cfc3.bindPopup(popup_171ab074b3a3be19878bcd23d229ead5)
#         ;
#
#
#
#
#             marker_0c81644c36fbb4da0a08e69e62e7cfc3.bindTooltip(
#                 `&lt;div&gt;
#                      Click for further information
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1ac87cf3886ff652e25a624c3bc5c159 = L.marker(
#                 [-31.952118, 115.85807],
#                 {}
#             ).addTo(feature_group_c6190a4b210b68f75c12bbbd78f531d8);
#
#
#         var popup_aedada3eeb5097afdc984a8cc9a3d75f = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_c3c72ada5f5380f9b6a5eef69502111a = $(`&lt;div id=&quot;html_c3c72ada5f5380f9b6a5eef69502111a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Name:&lt;/strong&gt; East Village&lt;br&gt;&lt;strong&gt;Category:&lt;/strong&gt; American&lt;br&gt;&lt;strong&gt;Activities:&lt;/strong&gt; American&lt;br&gt;&lt;br&gt;&lt;strong&gt;Price:&lt;/strong&gt; $$&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&lt;strong&gt;Rating:&lt;/strong&gt; 3.8&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&lt;strong&gt;Reviews:&lt;/strong&gt; 53&lt;br&gt;&lt;strong&gt;Address:&lt;/strong&gt; 140 William St, Perth, 6000&lt;br&gt;&lt;strong&gt;Phone:&lt;/strong&gt; +61 8 9322 8105&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_aedada3eeb5097afdc984a8cc9a3d75f.setContent(html_c3c72ada5f5380f9b6a5eef69502111a);
#
#
#
#         marker_1ac87cf3886ff652e25a624c3bc5c159.bindPopup(popup_aedada3eeb5097afdc984a8cc9a3d75f)
#         ;
#
#
#
#
#             marker_1ac87cf3886ff652e25a624c3bc5c159.bindTooltip(
#                 `&lt;div&gt;
#                      Click for further information
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dbd44f15900ae259b9ded70739459ea6 = L.marker(
#                 [-31.94902979, 115.858578],
#                 {}
#             ).addTo(feature_group_c6190a4b210b68f75c12bbbd78f531d8);
#
#
#         var popup_03df4d0d56567dce8b60be35540c1e7d = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_134c4462ce76a401a30c0d41dd9c6b3c = $(`&lt;div id=&quot;html_134c4462ce76a401a30c0d41dd9c6b3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Name:&lt;/strong&gt; Chimek Chicken &amp; Beer&lt;br&gt;&lt;strong&gt;Category:&lt;/strong&gt; American&lt;br&gt;&lt;strong&gt;Activities:&lt;/strong&gt; Chicken Shop, Beer Bar&lt;br&gt;&lt;br&gt;&lt;strong&gt;Price:&lt;/strong&gt; $&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&lt;strong&gt;Rating:&lt;/strong&gt; 3.3&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&lt;strong&gt;Reviews:&lt;/stron

# %% [markdown]
# ### Process and Print Horizontal Layer Plot.
